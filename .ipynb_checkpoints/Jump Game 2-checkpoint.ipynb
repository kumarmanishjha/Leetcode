# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def jump(self, nums: List[int]) -> int:
        
        
        jump_pos = []
        jump_pos_val = []
        
        #First element
        jump_pos.append[0]
        jump_pos_val.append(nums[0])
        jump_distance = sum(jump_pos)
        
        i = 0
        
        while(jump_distance <= len(nums)):
                
        last_pos = jump_pos[-1]
        last_pos_val = jump_pos_val[-1]
        
        if(last_pos + last_pos_val < len(nums)):
            i += 1
            #Check if current element can be reached by one before previous
            if(last_pos[])
